# %%
import pandas as pd
import sys
sys.path.append('../src/')
# %matplotlib inline
import numpy as np
from net.modules import *

# %%
model = UNETNiLM()
model
# Out:
# UNETNiLM(
#   (unet): UNetBaseline(
#     (layers): ModuleList(
#       (0): DoubleConv(
#         (net): Sequential(
#           (0): Conv1D(
#             (conv): Conv1d(1, 16, kernel_size=(3,), stride=(2,), padding=(1,))
#             (net): Sequential(
#               (0): Conv1d(1, 16, kernel_size=(3,), stride=(2,), padding=(1,))
#               (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): PReLU(num_parameters=1)
#             )
#           )
#           (1): Conv1D(
#             (conv): Conv1d(16, 16, kernel_size=(3,), stride=(2,), padding=(1,))
#             (net): Sequential(
#               (0): Conv1d(16, 16, kernel_size=(3,), stride=(2,), padding=(1,))
#               (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): PReLU(num_parameters=1)
#             )
#           )
#         )
#       )
#       (1): Down(
#         (net): Sequential(
# ...

# %%
x = torch.randn(4, 100, 1)

# %%
model(x)
# Out:
# (tensor([[[-0.0602, -0.4627,  0.1014,  0.0559, -0.1740],
#           [ 0.1705, -0.1476, -0.3523,  0.0168, -0.0439]],
#
#          [[ 0.5995, -0.3672, -0.2074,  0.2066,  0.2481],
#           [ 0.0834,  0.0580, -0.1446, -0.6429, -0.3805]],
#
#          [[ 0.2487, -0.2486,  0.0398, -0.2398,  0.2532],
#           [-0.0555,  0.0499, -0.1436, -0.2094, -0.2735]],
#
#          [[-0.0386, -0.1274, -0.0033, -0.0139,  0.2323],
#           [-0.0344,  0.3192, -0.2289,  0.0473, -0.2769]]],
#         grad_fn=<ViewBackward>),
#  tensor([[[ 0.1677, -0.1897, -0.3496,  0.3898,  0.0928],
#           [ 0.1150,  0.2459, -0.1536,  0.1371, -0.1799],
#           [-0.1891, -0.0437, -0.3143,  0.2495, -0.0788]],
#
#          [[ 0.1765, -0.1233, -0.1090, -0.2101, -0.2684],
#           [ 0.2594,  0.2763, -0.1277,  0.0510,  0.1241],
#           [ 0.0165, -0.0370, -0.4094,  0.3155,  0.4849]],
#
#          [[ 0.2503, -0.0948, -0.2279,  0.4374, -0.1173],
#           [-0.0216,  0.5389, -0.1635, -0.1712,  0.4497],
# ...

# %%
s, p=model(x)

# %%
p.shape
